# %%
from IPython.display import HTML
import random

def hide_toggle(for_next=False):
    this_cell = """$('div.cell.code_cell.rendered.selected')"""
    next_cell = this_cell + '.next()'

    toggle_text = 'Toggle show/hide'  # text shown on toggle link
    target_cell = this_cell  # target cell to control with toggle
    js_hide_current = ''  # bit of JS to permanently hide code in current cell (only when toggling next cell)

    if for_next:
        target_cell = next_cell
        toggle_text += ' next cell'
        js_hide_current = this_cell + '.find("div.input").hide();'

    js_f_name = 'code_toggle_{}'.format(str(random.randint(1,2**64)))

    html = """
        <script>
            function {f_name}() {{
                {cell_selector}.find('div.input').toggle();
            }}

            {js_hide_current}
        </script>

        <a href="javascript:{f_name}()">{toggle_text}</a>
    """.format(
        f_name=js_f_name,
        cell_selector=target_cell,
        js_hide_current=js_hide_current, 
        toggle_text=toggle_text
    )

    return HTML(html)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_16830495031654011878() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_16830495031654011878()">Toggle show/hide</a>

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
#import wordcloud
from wordcloud.wordcloud import WordCloud
from collections import Counter

# %%
import warnings 
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
warnings.filterwarnings(action='once')

# %%
lyrics = pd.read_csv('/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj1--Sixuan-Li/output/dt_lyrics.csv')
artists = pd.read_csv('/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj1--Sixuan-Li/data/artists.csv')

# %%
lyrics.head()
# Out:
#    Unnamed: 0                   song  year artist    genre  \
# 0           1  when-you-were-with-me  2009      a  Hip-Hop
# 1           2       careless-whisper  2009      a  Hip-Hop
# 2           3                   2-59  2007      a  Hip-Hop
# 3           4        power-of-desire  2007      a  Hip-Hop
# 4           5     you-re-not-in-love  2007      a  Hip-Hop
#
#                                               lyrics  id  \
# 0  I stopped by the house we called our home\nIt ...   1
# 1  I feel so unsure\nAs I take your hand and lead...   2
# 2  Mark:] Sunday football I got boot off the pitc...   3
# 3  [Chris:] Fallin' for a fantasy\nI threw away m...   4
# 4  something in the way we touch\nyou hold my han...   5
#
#                                         stemmedwords
# 0  stop house call home rundown grass overgrown s...
# 1  unsure hand lead dance floor music die eyes ca...
# 2  mark sunday football boots pitch people gamble...
# 3  chris fallin fantasy threw destiny stop feelin...
# 4  touch hold hand hold somethings change somethi...

# %%
artists_filter = artists.dropna()

# %%
result = pd.concat([lyrics, artists_filter], axis=1, join='inner',keys = ['artist','Artist'])

# %%
result
# Out:
#          artist                                                           \
#      Unnamed: 0                                               song  year
# 7             8                                           stranger  2013
# 9            10                                        die-tonight  2005
# 17           18                                         2nd-coming  2005
# 22           23                                       took-it-away  2002
# 26           27                                      shut-yer-face  2002
# 28           29                                        w-d-y-c-a-i  2002
# 29           30                                         going-down  2002
# 61           62                                      t-shirt-money  2008
# 63           64                                        french-kiss  2008
# 74           75                                     frequent-flyer  2007
# 76           77                                such-a-bad-comedown  2007
# 78           79                                    walking-the-cow  2007
# 92           93                                                red  2007
# 108         109                                       pearl-summer  2007
# 142         143                            if-it-means-alot-to-you  2009
# 148         149                                          heartless  2007
# 150         151                                 start-the-shooting  2007
# 155         156                                if-looks-could-kill  2007
# 159         160             your-way-with-words-is-through-silence  2007
# 165         166                                        dead-buried  2013
# 173         174                                   i-m-already-gone  2013
# 174         175                                           violence  2013
# 175         176  sometimes-you-re-the-hammer-sometimes-you-re-t...  2013
# 195         196                                 forgive-and-forget  2016
# 201         202                                     same-about-you  2016
# 208         209                          casablanca-sucked-anyways  2015
# 228         229                                      coming-around  2009
# 297         298                                        suicide-day  2006
# 310         311                                    out-in-the-dark  2007
# 322         323                                          mind-bomb  2007
# ...         ...                                                ...   ...
# 2345       2346                dee-wee-my-friend-the-massive-idiot  2006
# 2357       2358                                                ten  2016
# 2366       2367                                 don-t-you-remember  2011
# 2371       2372                                   rolling-the-deep  2011
# 2377       2378                                             fiasco  2011
# 2391       2392                                       send-my-love  2015
# 2416       2417                                never-tear-us-apart  2014
# 2422       2423                                 dirty-little-thing  2009
# 2442       2443                                        good-enough  2011
# 2448       2449                                     cage-the-beast  2011
# 2458       2459                                     dog-on-a-leash  2014
# 2463       2464                                     something-more  2014
# 2469       2470                                         life-sucks  2009
# 2477       2478                                         the-losers  2007
# 2493       2494                    better-living-through-chemistry  2005
# 2494       2495                                         vikraphone  2005
# 2514       2515                                           immortal  2002
# 2535       2536                                       sexual-needs  2007
# 2584       2585                                        allen-hotel  2007
# 2627       2628                                    the-ideal-woman  2005
# 2644       2645                                          model-man  2006
# 2672       2673                                     house-of-cards  2006
# 2674       2675                                       i-walk-alone  2006
# 2677       2678                                    something-to-do  2006
# 2681       2682                                     walking-on-air  2006
# 2693       2694                                     i-am-what-i-am  2006
# 2709       2710                            three-of-a-perfect-pair  2006
# 2745       2746                              we-won-t-let-you-down  2007
# 2755       2756                                    freedom-fighter  2012
# 2758       2759                                love-in-an-elevator  2012
#
#                                     \
#                    artist    genre
# 7                       a  Hip-Hop
# 9                       a  Hip-Hop
# 17                      a  Hip-Hop
# 22                      a  Hip-Hop
# 26                      a  Hip-Hop
# 28                      a  Hip-Hop
# 29                      a  Hip-Hop
# 61                      a  Hip-Hop
# 63                      a  Hip-Hop
# 74                 a-camp      Pop
# 76                 a-camp      Pop
# 78                 a-camp      Pop
# 92     a-canorous-quintet    Metal
# 108      a-change-of-pace     Rock
# 142     a-day-to-remember      Pop
# 148     a-day-to-remember      Pop
# 150     a-day-to-remember      Pop
# 155     a-day-to-remember      Pop
# 159     a-day-to-remember      Pop
# 165     a-day-to-remember      Pop
# 173     a-day-to-remember      Pop
# 174     a-day-to-remember      Pop
# 175     a-day-to-remember      Pop
# 195     a-day-to-remember      Pop
# 201     a-day-to-remember      Pop
# 208     a-day-to-remember      Pop
# 228         a-fine-frenzy      Pop
# 297   a-flock-of-seagulls      Pop
# 310       a-global-threat     Rock
# 322       a-global-threat     Rock
# ...                   ...      ...
# 2345         adam-sandler     Rock
# 2357          adamn-killa  Hip-Hop
# 2366                adele      Pop
# 2371                adele      Pop
# 2377                adele      Pop
# 2391                adele      Pop
# 2416                adele      Pop
# 2422         adelitas-way     Rock
# 2442         adelitas-way     Rock
# 2448         adelitas-way     Rock
# 2458         adelitas-way     Rock
# 2463         adelitas-way     Rock
# 2469                adema     Rock
# 2477                adema     Rock
# 2493                adema     Rock
# 2494                adema     Rock
# 2514                adema     Rock
# 2535         adina-howard  Hip-Hop
# 2584          adolescents     Rock
# 2627         adrian-belew     Rock
# 2644         adrian-belew     Rock
# 2672         adrian-belew     Rock
# 2674         adrian-belew     Rock
# 2677         adrian-belew     Rock
# 2681         adrian-belew     Rock
# 2693         adrian-belew     Rock
# 2709         adrian-belew     Rock
# 2745            aerosmith     Rock
# 2755            aerosmith     Rock
# 2758            aerosmith     Rock
#
#                                                                \
#                                                  lyrics    id
# 7     If it's one thing I've learned that I've writt...     8
# 9     Lose yourself, save yourself\nOne more night, ...    10
# 17    If your happy and you know it clap your hands\...    18
# 22    Five pretty boys for ten shitty years\nFive gi...    23
# 26    So come out fighting, second's out\nWho's the ...    27
# 28    I'm so tired, I need sleep\nI'm talking to my ...    29
# 29    Suck it up, we're going down\n30 seconds 'till...    30
# 61    Who is the man, who is the man\nWho is the man...    62
# 63    Days are gone\nDays are long and youre\nYoure ...    64
# 74    Would you help me pack my bags\nI might be lea...    75
# 76    I danced for a while\nAnd my moves\nWould make...    77
# 78    Try to remember\nBut my feelings\nCan't know f...    79
# 92    Trust! The blind man leads the way\nA burnt ou...    93
# 108   You're my sun, my moon, my skies\nYou're my ev...   109
# 142   Hey darling, I hope you're good tonight\nAnd I...   143
# 148   For once my eyes are open to you\nAnd everythi...   149
# 150   Hey boys, look where we are\nThis town ain't b...   151
# 155   Something's wrong and it's not me for once\nAn...   156
# 159   If affection spoke louder than words, you'd ma...   160
# 165   Let me find the way that I can make do\nWithou...   166
# 173   As I look round this make shift moving house\n...   174
# 174   I've been feeling like everything is for nothi...   175
# 175   You wanna take, take, take, take, take it away...   176
# 195   I feel like a runaway\nSeeing the light of day...   196
# 201   I just felt a wave, an emotion, and right then...   202
# 208   I've spent so much time trying to fix your lif...   209
# 228   Ladders,\nChutes and ladders,\nCutting new clo...   229
# 297   I've got a question\nI've got a question you s...   298
# 310   last Seems like so many nights\nGet your bust ...   311
# 322   You'll listen if I shout\nWho cares what it's ...   323
# ...                                                 ...   ...
# 2345  He said he'd be here at seven\nThe clock just ...  2346
# 2357  [Intro]\nAdamn\nI walk up in the store bitch I...  2358
# 2366  When will I see you again?\nYou left with no g...  2367
# 2371  (Verse 1)\nThere's a fire starting in my heart...  2372
# 2377  I'm insane in the brain\nYou're not already......  2378
# 2391  Just the guitar\nThis was all you, none of it ...  2392
# 2416  Don't ask me\nWhat you know is true\nDon't hav...  2417
# 2422  I like it when you're watching me\nYou grind y...  2423
# 2442  I know what's coming\nYou've taken me down thi...  2443
# 2448  I see it in your eyes\nYou're feeling paranoid...  2449
# 2458  I see it coming, I'm supposed to follow\nNo, I...  2459
# 2463  Sometimes the dreams you have are burning down...  2464
# 2469  Try and put me down\nYou cant comprehend\nIn t...  2470
# 2477  I'd like to thank you all for having me\nIn th...  2478
# 2493  One little request changes life for your best ...  2494
# 2494  You're not thinking, with your mind,\nyou'll r...  2495
# 2514  We're face to face\nLoyalty is what I need to ...  2515
# 2535  soon as you come in\nthat's where the dream be...  2536
# 2584  Sometimes at night I drive by and stare\nAnd w...  2585
# 2627  She's demure...friendly...loving and good-look...  2628
# 2644  Look at the signs\nLook at the symptoms\nLook ...  2645
# 2672  People like us have our eyes on the stars\nAnd...  2673
# 2674  I walk alone where the streets are paved with ...  2675
# 2677  Try to lose your attitude, put it in your boot...  2678
# 2681  Close your eyes and look at me\nI'll be standi...  2682
# 2693  "Friends seen an` unseen...to you that are rid...  2694
# 2709  She is susceptible\nHe is impossible\nThey hav...  2710
# 2745  Won't let you down\nThis time around\nWon't le...  2746
# 2755  Oh, oh, oh\nWhoa, whoa, whoa\nI'm a freedom fi...  2756
# 2758  Workin' like a dog fo de boss man (oh)\nWorkin...  2759
#
#                                                          \
#                                            stemmedwords
# 7     ive learn ive written paper leave weed table s...
# 9     lose save night time arrive time hear cry toni...
# 17    happy clap hand clap clap happy clap hand clap...
# 22    pretty boy ten shitty girl door ear reaction r...
# 26    fight whos daddy doubt brain act youre alright...
# 28    tired sleep talk pillow whats wrong mistake th...
# 29    suck till smash ground passenger lost smile bo...
# 61    control clean floor mend door stuck half mount...
# 63    day day youre youre shoulder youre wrong carry...
# 74    pack bag leave sweet assistance steal time hop...
# 76    dance move smile love dear chemical lover veil...
# 78    remember feeling tryin reach lucky stars eyes ...
# 92    trust blind lead burnt candle hand chase etern...
# 108   youre sun moon sky youre youre sun moon sky yo...
# 142   darling hope youre tonight leave sweet home ti...
# 148   eyes youve web lie left act burden ive finally...
# 150   boy town ready run notice single rumors spread...
# 155   somethings wrong youll call crazy hate straigh...
# 159   affection spoke louder words youd deaf easy lo...
# 165   circumstance follow desperate trust trouble mi...
# 173   round shift move house searching whatevers lef...
# 174   ive feeling ive god damn searching bright stre...
# 175   waiting waiting waiting waiting waiting till s...
# 195   runaway light day time draw line hard care slo...
# 201   wave emotion change miss id wrong gotta step p...
# 208   ive spent time fix life forgot mine time putti...
# 228   ladder chute ladder cut clothes grandparents p...
# 297   ive question ive question answer answer sob re...
# 310   night bust dusk kill light ahead swill cadilla...
# 322   youll listen shout care bible record sleeve ea...
# ...                                                 ...
# 2345  hed clock hit cold waiting ride watch mama doo...
# 2357  intro adamn walk store bitch ten adamn hook ad...
# 2366  left goodbye single words finally kiss seal id...
# 2371  verse fire start heart reach fever pitch bring...
# 2377  insane brain youre pain run veins piss pretent...
# 2391  guitar hand body told umm told ready jump id l...
# 2416  true love precious heart stand world collide t...
# 2422  youre watch grind teeth wall late night shes w...
# 2442  whats coming youve road somethings miss time y...
# 2448  eyes youre feeling paranoid ive ive deep insid...
# 2458  coming supposed follow hold chain brain live h...
# 2463  dream burn walk care rules telling arent ive d...
# 2469  comprehend life ive hold tounge lie life givin...
# 2477  id village fill tragedy miss swear doesnt chec...
# 2493  request life selfcontrol doctor line pocket pa...
# 2494  youre thinking mind youll remember surender pr...
# 2514  loyalty youre insecure fear breed heart chorus...
# 2535  dream begane pain youve waiting inside deal gr...
# 2584  night drive stare life wounds walk dread conde...
# 2627  shes demurefriendlyloving goodlooking goodlook...
# 2644  sign symptoms slightly calm storm silence sign...
# 2672  people eyes stars information tv guide enterta...
# 2674  walk street paved lover theyre hand hand theyr...
# 2677  lose attitude boots stick sun doesnt shine tim...
# 2681  close eyes ill stand deep blue sea shelter sky...
# 2693  friend unseento ridin automobileto sit table g...
# 2709  susceptible impossible cross share perfect pai...
# 2745  time leaf clover symbol head mind love doubt e...
# 2755  whoa whoa whoa freedom fighter hear lie truth ...
# 2758  workin dog fo de boss workin de company bettin...
#
#                          Artist  \
#                          Artist
# 7           a-flock-of-seagulls
# 9                          a-ha
# 17                         abba
# 22                      aborted
# 26                        ac-dc
# 28                       accept
# 29                   acceptance
# 61                    aerosmith
# 63                          afi
# 74                   against-me
# 76                     agalloch
# 78                 agent-orange
# 92                   air-supply
# 108                     alabama
# 142                alexisonfire
# 148             alice-in-chains
# 150              alien-ant-farm
# 155               alkaline-trio
# 159        all-american-rejects
# 165                all-time-low
# 173                    allister
# 174                allman-brors
# 175        allman-brothers-band
# 195               amber-pacific
# 201                     america
# 208                 amon-amarth
# 228                    anberlin
# 297                   anti-flag
# 310                       anvil
# 322                  april-wine
# ...                         ...
# 2345              fleetwood-mac
# 2357             flogging-molly
# 2366                    flyleaf
# 2371                      focus
# 2377               foo-fighters
# 2391         fountains-of-wayne
# 2416  frankie-goes-to-hollywood
# 2422            franz-ferdinand
# 2442              frenzal-rhomb
# 2448       from-autumn-to-ashes
# 2458                     fugazi
# 2463       funeral-for-a-friend
# 2469      further-seems-forever
# 2477       g-love-special-sauce
# 2493               gang-of-four
# 2494                    garbage
# 2514                    gasolin
# 2535                    genesis
# 2584                gipsy-kings
# 2627                   godflesh
# 2644              goo-goo-dolls
# 2672        grand-funk-railroad
# 2674                  grandaddy
# 2677          grant-lee-buffalo
# 2681               grave-digger
# 2693             the-academy-is
# 2709             the-black-keys
# 2745                 the-eagles
# 2755           the-four-seasons
# 2758            the-get-up-kids
#
#                                                                  \
#                                                   Intro  Formed
# 7     \n                                        Form...  1980.0
# 9     \n                                        Norw...  1982.0
# 17    \n                                        Agne...  1971.0
# 22    \n                                        Belg...  1995.0
# 26    \n                                        Hard...  1973.0
# 28    \n                                        Germ...  1978.0
# 29    \n                                        Fina...  1998.0
# 61    \n                                        Aero...  1970.0
# 63    \n                                        Shor...  1991.0
# 74    \n                                        Punk...  1997.0
# 76    \n                                        Agal...  1995.0
# 78    \n                                        Infl...  1979.0
# 92    \n                                        Aust...  1976.0
# 108   \n                                        Alab...  1977.0
# 142   \n                                        Alex...  2001.0
# 148   \n                                        Alte...  1987.0
# 150   \n                                        Alte...  1995.0
# 155   \n                                        Melo...  1997.0
# 159   \n                                        The ...  2000.0
# 165   \n                                        All ...  2003.0
# 173   \n                                        Alli...  1996.0
# 174   \n                                        Amer...  1969.0
# 175   \n                                        Amer...  1969.0
# 195   \n                                        Amer...  2002.0
# 201   \n                                        Form...  1967.0
# 208   \n                                        The ...  1992.0
# 228   \n                                        Alte...  2001.0
# 297   \n                                        Poli...  1994.0
# 310   \n                                        Cana...  1978.0
# 322   \n                                        Cana...  1969.0
# ...                                                 ...     ...
# 2345  \n                                        Foun...  1967.0
# 2357  \n                                        Flog...  1997.0
# 2366  \n                                        Flyl...  2000.0
# 2371  \n                                        Dutc...  1969.0
# 2377  \n                                        Alte...  1995.0
# 2391  \n                                        Foun...  1996.0
# 2416  \n                                        Engl...  1980.0
# 2422  \n                                        Fran...  2001.0
# 2442  \n                                        Fren...  1993.0
# 2448  \n                                        Melo...  2000.0
# 2458  \n                                        Hard...  1987.0
# 2463  \n                                        Wels...  2001.0
# 2469  \n                                        Alth...  1999.0
# 2477  \n                                        Amer...  1992.0
# 2493  \n                                        Engl...  1977.0
# 2494  \n                                        Alte...  1993.0
# 2514  \n                                        As o...  1969.0
# 2535  \n                                        Form...  1966.0
# 2584  \n                                        Nico...  1979.0
# 2627  \n                                        Expe...  1988.0
# 2644  \n                                        Alte...  1985.0
# 2672  \n                                        Form...  1968.0
# 2674  \n                                        Amer...  1992.0
# 2677  \n                                        Amer...  1992.0
# 2681  \n                                        Heav...  1980.0
# 2693  \n                                        The ...  2002.0
# 2709  \n                                        The ...  2001.0
# 2745  \n                                        Foun...  1971.0
# 2755  \n                                        Amer...  1961.0
# 2758  \n                                        USA ...  1994.0
#
#                                                          \
#                                                 Members
# 7     \n                                            ...
# 9     \n                                            ...
# 17    \n                                            ...
# 22    \n                                            ...
# 26    \n                                            ...
# 28    \n                                            ...
# 29    \n                                            ...
# 61    \n                                            ...
# 63    \n                                            ...
# 74    \n                                            ...
# 76    \n                                            ...
# 78    \n                                            ...
# 92    \n                                            ...
# 108   \n                                            ...
# 142   \n                                            ...
# 148   \n                                            ...
# 150   \n                                            ...
# 155   \n                                            ...
# 159   \n                                            ...
# 165   \n                                            ...
# 173   \n                                            ...
# 174   \n                                            ...
# 175   \n                                            ...
# 195   \n                                            ...
# 201   \n                                            ...
# 208   \n                                            ...
# 228   \n                                            ...
# 297   \n                                            ...
# 310   \n                                            ...
# 322   \n                                            ...
# ...                                                 ...
# 2345  \n                                            ...
# 2357  \n                                            ...
# 2366  \n                                            ...
# 2371  \n                                            ...
# 2377  \n                                            ...
# 2391  \n                                            ...
# 2416  \n                                            ...
# 2422  \n                                            ...
# 2442  \n                                            ...
# 2448  \n                                            ...
# 2458  \n                                            ...
# 2463  \n                                            ...
# 2469  \n                                            ...
# 2477  \n                                            ...
# 2493  \n                                            ...
# 2494  \n                                            ...
# 2514  \n                                            ...
# 2535  \n                                            ...
# 2584  \n                                            ...
# 2627  \n                                            ...
# 2644  \n                                            ...
# 2672  \n                                            ...
# 2674  \n                                            ...
# 2677  \n                                            ...
# 2681  \n                                            ...
# 2693  \n                                            ...
# 2709  \n                                            ...
# 2745  \n                                            ...
# 2755  \n                                            ...
# 2758  \n                                            ...
#
#
#                                Origin
# 7                  Liverpool, England
# 9                        Oslo, Norway
# 17                  Stockholm, Sweden
# 22                            Belgium
# 26                  Sydney, Australia
# 28                            Germany
# 29                        Seattle, WA
# 61                         Boston, MA
# 63                          Ukiah, CA
# 74                    Gainesville, FL
# 76                       Portland, OR
# 78                      Fullerton, CA
# 92               Melbourne, Australia
# 108                    Fort Payne, AL
# 142   St. Catharines, Ontario, Canada
# 148                       Seattle, WA
# 150                     Riverside, CA
# 155                       Chicago, IL
# 159                    Stillwater, OK
# 165                     Baltimore, MD
# 173                       Chicago, IL
# 174                         Macon, GA
# 175                         Macon, GA
# 195                       Seattle, WA
# 201                   London, England
# 208                     Tumba, Sweden
# 228                  Winter Haven, FL
# 297                    Pittsburgh, PA
# 310                            Canada
# 322      Halifax, Nova Scotia, Canada
# ...                               ...
# 2345                  London, England
# 2357                  Los Angeles, CA
# 2366                       Belton, TX
# 2371       Amsterdam, The Netherlands
# 2377                      Seattle, WA
# 2391                     New York, NY
# 2416               Liverpool, England
# 2422                Glasgow, Scotland
# 2442                Sydney, Australia
# 2448                  Long Island, NY
# 2458                 Washington, D.C.
# 2463            Bridgend, South Wales
# 2469                Pompano Beach, FL
# 2477                 Philadelphia, PA
# 2493                   Leeds, England
# 2494                      Madison, WI
# 2514                          Denmark
# 2535               Godalming, England
# 2584                    Arles, France
# 2627              Birmingham, England
# 2644                      Buffalo, NY
# 2672                        Flint, MI
# 2674                      Modesto, CA
# 2677                  Los Angeles, CA
# 2681                          Germany
# 2693              Hoffman Estates, IL
# 2709                        Akron, OH
# 2745                  Los Angeles, CA
# 2755                       Newark, NJ
# 2758                  Kansas City, MO
#
# [253 rows x 13 columns]

# %%
keep_coulms_label = [ 'song', 'year', 'artist', 'genre', 'id', 'stemmedwords']

# %%
lyrics.head()
# Out:
#    Unnamed: 0                   song  year artist    genre  \
# 0           1  when-you-were-with-me  2009      a  Hip-Hop
# 1           2       careless-whisper  2009      a  Hip-Hop
# 2           3                   2-59  2007      a  Hip-Hop
# 3           4        power-of-desire  2007      a  Hip-Hop
# 4           5     you-re-not-in-love  2007      a  Hip-Hop
#
#                                               lyrics  id  \
# 0  I stopped by the house we called our home\nIt ...   1
# 1  I feel so unsure\nAs I take your hand and lead...   2
# 2  Mark:] Sunday football I got boot off the pitc...   3
# 3  [Chris:] Fallin' for a fantasy\nI threw away m...   4
# 4  something in the way we touch\nyou hold my han...   5
#
#                                         stemmedwords
# 0  stop house call home rundown grass overgrown s...
# 1  unsure hand lead dance floor music die eyes ca...
# 2  mark sunday football boots pitch people gamble...
# 3  chris fallin fantasy threw destiny stop feelin...
# 4  touch hold hand hold somethings change somethi...

# %%
genre_list = list(set(lyrics['genre']))
genre_list
# Out:
# ['Jazz',
#  'Pop',
#  'Indie',
#  'Country',
#  'Hip-Hop',
#  'Rock',
#  'R&B',
#  'Electronic',
#  'Not Available',
#  'Metal',
#  'Other',
#  'Folk']

# %%
lyrics['genre'].value_counts().plot.bar()

# %%
def df_genre(genre):
    """sub original lyrics dataframe by genre
    Input
    ------
        genre: different genre, a list, no duplicate variable
    Return
    ------
        dataframe that only contain rows that belong to input genre"""
    dataframe_all =  lyrics[lyrics['genre']==genre]
    return dataframe_all[keep_coulms_label]
    
def series_stemmedwords (dataframe_genre):
    """return a pandas series that only contain stemmedwords"""
    return dataframe_genre['stemmedwords']

def df_add_words(dataframe_genre):
    #https://sigdelta.com/blog/text-analysis-in-pandas/
    dataframe_genre_add = dataframe_genre.copy()
    dataframe_genre_add['words'] = dataframe_genre_add.stemmedwords.str.strip().str.split('[\W_]+')
    return dataframe_genre_add

def list_all_words(dataframe_add):
    """get a list contain all words in stemmwords
    Input
    -----
        dataframe_add : a dataframe, should be the one add words col
    Return
    ----
        a list contain every words from words col"""

    combine_list_words = list()
    for l in dataframe_add['words']:
        combine_list_words.append(l)
    combine_list_words = [val for sublist in combine_list_words for val in sublist] 
    return combine_list_words

def float_words_using(dataframe_add):
    return len(set(list_all_words(dataframe_add)))/len(list_all_words(dataframe_add))

def df_counts_words(list_words,int_common):
    """get a df with only words and counts
    Input
    ----
        list_words: a list of words that want to count,should be the output of list_all_words
        int_common: a int, the first how many words with highest freq want to show
    Return
    ------
        a dataframe that only contain words and counts, from max to min order"""
    counts = Counter(list_words)
    df_counts = pd.DataFrame(
    {'words': 
list(counts.keys()),
     'counts': 
list(counts.values())
    })
    df_counts = df_counts.sort_values('counts',ascending=False)
    if int_common is not None:
        return df_counts.iloc[0:int_common]
    return df_counts

def word_cloud_plot(list_words,int_common=None):
    #https://stackoverflow.com/questions/38465478/wordcloud-from-data-frame-with-frequency-python
    d = {}
    for a, x in df_counts_words(list_words,int_common).values:
        d[a] = x
    #convert list to string and generate
    unique_string=(" ").join(list_words)
    wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
    wordcloud.generate_from_frequencies(frequencies=d)
    plt.figure(figsize=(15,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.savefig("your_file_name"+".png", bbox_inches='tight')
    plt.show()
    plt.close()

def word_cloud_via_genre(genre,int_common=None):
    """main function for word cloud via genre
    Inputs
    ----
        genre: string
        int_common: integer,choose how many rows form df, the highest freq of words
    Return
    ----
        a plot of wordcloud"""
    dataframe_genre = df_genre(genre)
    dataframe_add = df_add_words(dataframe_genre)
    list_words = list_all_words(dataframe_add)
    
    return word_cloud_plot(list_words,int_common)

# %%
word_cloud_via_genre('Rock',int_common=10)

# %%
word_cloud_via_genre('Pop',int_common=10)

# %%
word_cloud_via_genre('Folk',int_common=10)

# %%
df_add_pop = df_add_words(df_genre('Pop'))
l_pop = list_all_words(df_add_pop)
