# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {## <font color='green'>Packages</font>

import wordcloud
from wordcloud import WordCloud

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
#import wordcloud
#from wordcloud.wordCcloud import WordCloud
from collections import Counter
import numpy as np

# import warnings 
# warnings.filterwarnings('ignore')
# warnings.simplefilter('ignore')
# warnings.filterwarnings(action='once')
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {## <font color='green'>Packages</font>
#
# import wordcloud
# from wordcloud import WordCloud
#
# import pandas as pd
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# #import wordcloud
# #from wordcloud.wordCcloud import WordCloud
# from collections import Counter
# import numpy as np
#
# # import warnings
# # warnings.filterwarnings('ignore')
# # warnings.simplefilter('ignore')
# # warnings.filterwarnings(action='once')
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ## <font color='green'>Packages</font>

# %%
import wordcloud
from wordcloud import WordCloud

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
#import wordcloud
#from wordcloud.wordCcloud import WordCloud
from collections import Counter
import numpy as np

# %%
# import warnings 
# warnings.filterwarnings('ignore')
# warnings.simplefilter('ignore')
# warnings.filterwarnings(action='once')

# %% [markdown]
# ## <font color='green'>Data & Global variable</font>
#
# I joined lyrics (processed rdata file) and artist csv file together and drop the NAN values.
# For lyrics anlysis, only original lyrics file will be used.

# %%
lyrics = pd.read_csv('/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj1--Sixuan-Li/output/dt_lyrics.csv')
artists = pd.read_csv('/Users/rong/Documents/Columbia_python_jupyter_notebook/fall2019-proj1--Sixuan-Li/data/artists.csv')

# %%
#some operation for data cleaning 
artists_filter = artists.dropna()
lyrics_copy = lyrics.copy()
#join df of aritst and lyrics drop all the NAN values
df_join_lyrics_artist = lyrics_copy.join(artists_filter.set_index('Artist'), on = 'artist').dropna()

# %%
#Global varibales, cols that would be keeped
keep_coulms_label = [ 'song', 'year', 'artist', 'genre', 'id', 'stemmedwords']
keep_label_join = ['year', 'artist', 'genre', 'stemmedwords', 'Intro', 'Formed', 'Members', 'Origin']

# %%
genre_list = list(set(lyrics['genre']))
artist_list =  list(set(df_join_lyrics_artist['artist']))
origin_list = list(set(df_join_lyrics_artist['Origin']))

artist_1 =  artist_list[0:int(len(artist_list)/2)] 
artist_2 = [item for item in artist_list if item not in artist_1]

# %% [markdown]
# ## <font color='green'>Some EDA work</font>

# %%
len(list(set(artists_filter['Origin'])))/len(list(artists_filter['Origin']))
# Out:
# 0.5652173913043478

# %%
len(list(set(artists_filter['Formed'])))/len(list(artists_filter['Formed'])) #different year
# Out:
# 0.16600790513833993

# %%
len(list(set(artists_filter['Artist'])))/len(list(artists_filter['Artist']))
# Out:
# 1.0

# %% [markdown]
# #### Genreal plot to see how many songs were in lyrics file regarding to different genre

# %%
lyrics['genre'].value_counts().plot.bar()

# %% [markdown]
# #### Genreal plot to see how many songs were in lyrics file regarding to different formed year

# %%
df_join_lyrics_artist['Formed'].value_counts().plot.bar()

# %%
df_join_lyrics_artist['Origin'].value_counts().plot.bar()

# %%
def df_genre(genre):
    """sub original lyrics dataframe by genre
    Input
    ------
        genre: different genre, a string
    Return
    ------
        dataframe that only contain rows that belong to input genre"""
    dataframe_all =  lyrics[lyrics['genre']==genre]
    return dataframe_all[keep_coulms_label]


def df_genre_joined(genre):
    """sub original lyrics dataframe by genre
    Input
    ------
        genre: different genre, a string
    Return
    ------
        dataframe that only contain rows that belong to input genre"""
    dataframe_all =  df_join_lyrics_artist[df_join_lyrics_artist['genre'] == genre]
    return dataframe_all[keep_label_join]

def df_formed(formed):
    """sub original lyrics dataframe by formed yaer
    Input
    ------
        formed: different formed, a string
    Return
    ------
        dataframe that only contain rows that belong to input year"""
    dataframe_all =  df_join_lyrics_artist[df_join_lyrics_artist['Formed'] == formed]
    return dataframe_all[keep_label_join]

def df_artist(artist):
    """sub original lyrics dataframe by artist
    Input
    ------
        artist: different people, a string
    Return
    ------
        dataframe that only contain rows that belong to input artist"""
    dataframe_all =  df_join_lyrics_artist[df_join_lyrics_artist['artist'] == artist]
    return dataframe_all[keep_label_join]
    

def df_origin(origin_str):
    """sub original lyrics dataframe by origin
    Input
    ------
        origin_str: a string
    Return
    ------
        dataframe that only contain rows that belong to origin"""
    dataframe_all =  df_join_lyrics_artist[df_join_lyrics_artist['Origin'] == origin_str]
    return dataframe_all[keep_label_join]



    
def series_stemmedwords (dataframe_genre):
    """return a pandas series that only contain stemmedwords"""
    return dataframe_genre['stemmedwords']

def df_add_words(dataframe_genre):
    #https://sigdelta.com/blog/text-analysis-in-pandas/
    dataframe_genre_add = dataframe_genre.copy()
    dataframe_genre_add['words'] = dataframe_genre_add.stemmedwords.str.strip().str.split('[\W_]+')
    return dataframe_genre_add

def list_all_words(dataframe_add):
    """get a list contain all words in stemmwords
    Input
    -----
        dataframe_add : a dataframe, should be the one add words col
    Return
    ----
        a list contain every words from words col"""

    combine_list_words = list()
    for l in dataframe_add['words']:
        combine_list_words.append(l)
    combine_list_words = [val for sublist in combine_list_words for val in sublist] 
    return combine_list_words

def float_words_using(dataframe_add):
    return len(set(list_all_words(dataframe_add)))/len(list_all_words(dataframe_add))


def float_words_artist_main(artist_name):
    df_artisttest = df_artist(artist_name)
    df_artisttest_add = df_add_words(df_artisttest)
    return [artist_name,float_words_using(df_artisttest_add)]



def df_counts_words(list_words,int_common=None):
    """get a df with only words and counts
    Input
    ----
        list_words: a list of words that want to count,should be the output of list_all_words
        int_common: a int, the first how many words with highest freq want to show
    Return
    ------
        a dataframe that only contain words and counts, from max to min order"""
    counts = Counter(list_words)
    df_counts = pd.DataFrame(
    {'words': list(counts.keys()),
     'counts': list(counts.values())
    })
    df_counts = df_counts.sort_values('counts',ascending=False)
    if int_common is not None:
        return df_counts.iloc[0:int_common]
    return df_counts


def df_counts_word_main(classification_str,label,int_common = None):
    """dataframe of what words been used most by artist of genre
    Input
    ----
        classfication_str: a string, name of a artist or type of genre or origin_address
        label: artist, or type,string
        int_common: a int, show the most several words
    Return
    -----
        dataframe with words and time of words appear"""
    if label == 'artist':
        df_get = df_artist(classification_str)
        df_get_add = df_add_words(df_get)
        list_artist_add = list_all_words(df_get_add)
        return df_counts_words(list_artist_add,int_common)
    if label == 'genre':
        df_get = df_genre(classification_str)
        df_get_add = df_add_words(df_get)
        list_artist_add = list_all_words(df_get_add)
        return df_counts_words(list_artist_add,int_common)
    if label == 'origin':
        df_get = df_origin(classification_str)
        df_get_add = df_add_words(df_get)
        list_artist_add = list_all_words(df_get_add)
        return df_counts_words(list_artist_add,int_common)
    
    
    

def word_cloud_plot(list_words,int_common=None):
    
    #https://stackoverflow.com/questions/38465478/wordcloud-from-data-frame-with-frequency-python
    d = {}
    for a, x in df_counts_words(list_words,int_common).values:
        d[a] = x
    #convert list to string and generate
    unique_string=(" ").join(list_words)
    wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
    wordcloud.generate_from_frequencies(frequencies=d)
    plt.figure(figsize=(10,4))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.savefig("your_file_name"+".png", bbox_inches='tight')
    plt.show()
    plt.close()

def word_cloud_main(classification_str,label,int_common=None):
    """main function for word cloud via genre
    Input
    ----
        classfication_str: a string, name of a artist or type of genre or origin_address
        label: artist, or type,string
        int_common: a int, show the most several words
    Return
    ----
        a plot of wordcloud"""
    
    if label == 'artist':
        df_get = df_artist(classification_str)
        df_get_add = df_add_words(df_get)
        list_artist_add = list_all_words(df_get_add)
        return word_cloud_plot(list_artist_add,int_common)
    if label == 'genre':
        df_get = df_genre(classification_str)
        df_get_add = df_add_words(df_get)
        list_artist_add = list_all_words(df_get_add)
        return word_cloud_plot(list_artist_add,int_common)
    if label == 'origin':
        df_get = df_origin(classification_str)
        df_get_add = df_add_words(df_get)
        list_artist_add = list_all_words(df_get_add)
        return word_cloud_plot(list_artist_add,int_common)

def list_counts_common_word(label,var_list,int_common = None):
    """return a nested list with popular words count
    Input
    ------
        label: artist/genre,origin, string, uesed to classify the type
        var_list: origin_list, genre_list, artist_list
        int_common: how many most words want to show
    Return
    -----
        a nested list contain all int_common in given label"""
    l_test_sum = []
    if label == 'origin':
        for position in var_list:
            df_test = df_counts_word_main(position,'origin',int_common)
            l_test = list(df_test['words'])
            l_test_sum.append(l_test)
        return [val for sublist in l_test_sum for val in sublist] 
    if label == 'genre':
        for position in var_list:
            df_test = df_counts_word_main(position,'genre',int_common)
            l_test = list(df_test['words'])
            l_test_sum.append(l_test)
        return [val for sublist in l_test_sum for val in sublist] 
    if label == 'artist':
        for position in var_list:
            df_test = df_counts_word_main(position,'artist',int_common)
            l_test = list(df_test['words'])
            l_test_sum.append(l_test)
        return [val for sublist in l_test_sum for val in sublist] 
    
def bar_plot_freq(label,var_list,int_common,int_words = 10):
    """retun a bar plot to common words
    label: string
    int_common
    int_words:int, for how many words display in the plot"""
    if label == 'artist':
        l_list = list_counts_common_word('artist',var_list,int_common)
        df_test = df_counts_words(l_list,int_words)
        return plt.bar(df_test['words'],df_test['counts'])
    if label == 'genre':
        l_list = list_counts_common_word('genre',var_list,int_common)
        df_test = df_counts_words(l_list,int_words)
        return plt.bar(df_test['words'],df_test['counts'])
    if label == 'origin':
        l_list = list_counts_common_word('origin',var_list,int_common)
        df_test = df_counts_words(l_list,int_words)
        return plt.bar(df_test['words'],df_test['counts'])

# %% [markdown]
# ## <font color='green'>Topics : Popular words and vocabulary</font>
#
# #### Before we get started with the topic, let's have a quick glance on what words tends to appear in different lyrics:

# %%
for ly in genre_list:
    print(ly)
    word_cloud_main(ly,'genre',10)
# Out:
# Other
# Country
# Pop
# Electronic
# Rock
# R&B
# Not Available
# Indie
# Folk
# Metal
# Jazz
# Hip-Hop

# %% [markdown]
# #### It is not hard to see that for most lyrics, some popular words like "love","ill","time" tends to appear everywhere. Here is a bar plot of the intersection popular words in different lyrics:

# %%
bar_plot_freq('genre',genre_list,10)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #### How about origin? is there only several origin (ie, area) tends to use these words a lot? Let's do the same calculation again but to see what would be the intersection of most popular words in different origin:

# %%
bar_plot_freq('origin',origin_list,10)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ##### As you can see, not much different can be found, just some slightly order change among some words. Let's have a last try on this calculation, this time we consider the artist: Is there some artist, tends to use these "popular words" most while others doens't ?

# %%
bar_plot_freq('artist',artist_list,10)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #### Honestly with a roughly look at these three bar plot. I would say no intereting insight can be found at all! However, it remind me another direction of thinking the frequency of words appeared, which drive this topic: <font color='Red'>Do artist who has higher vocabulary also tends to use these "popular words"?</font>

# %% [markdown]
# ####  Let's have a quick look on how would artist's vocabulary vary. Here is the percentage of "unique" words appear in their works. The higher the percentage, the more vocabulary (at least it seems) the artist has. The first datafame shows the  first five artists who has relatively higher vocabulary while the second dataframe shows the last five with lower vocabulary. The range vary from 0.83 to 0.08, sounds a little bit fun now!

# %%
# A dataframe that counts for different artist, do they tend to repeat words or now. the larger the value is, the less likely they repeat the words
lists_artist_floatwords=[]
for name in artist_list:
    lists_artist_floatwords.append(float_words_artist_main(name))
df_artist_percentage_unique = pd.DataFrame(lists_artist_floatwords,columns=['artist','percentage_unique_words'])
df_artist_percentage_unique = df_artist_percentage_unique.sort_values('percentage_unique_words',ascending=False)

# %%
df_artist_percentage_unique.head(5)
# Out:
#         artist  percentage_unique_words
# 76       focus                 0.826087
# 70   daughters                 0.740648
# 237  cryptopsy                 0.675120
# 229   au-pairs                 0.662531
# 10     gasolin                 0.656566

# %%
df_artist_percentage_unique.tail(5)
# Out:
#            artist  percentage_unique_words
# 149         ac-dc                 0.116283
# 108  fall-out-boy                 0.115470
# 79    dragonforce                 0.114739
# 158      bon-jovi                 0.087382
# 194     daft-punk                 0.078746

# %% [markdown]
# #### Now let's dig it deeper to see what words tend to use often for those artist has lower vocabulary:

# %%
df_artist_percentage_larger = df_artist_percentage_unique[df_artist_percentage_unique['percentage_unique_words'] > 0.65]
artist_larger = list(df_artist_percentage_larger['artist'])
artist_smaller = [item for item in artist_list if item not in artist_larger]

# %%
bar_plot_freq('artist',artist_smaller,10)
# Out:
# <BarContainer object of 10 artists>

# %%
small_list = list_counts_common_word('artist',artist_smaller,10)
df_small = df_counts_words(small_list,None)
l_small = list(df_small['words'].head(10))
l_small
# Out:
# ['time', 'love', 'youre', 'ill', 'day', 'ive', 'life', 'eyes', 'baby', 'heart']

# %% [markdown]
# #### And let's also bring the list of the most popular words were being used among all artist (the first list) and to see the difference between these two (the second list)

# %%
l_list = list_counts_common_word('artist',artist_list,10)
df_test = df_counts_words(l_list,None).head(10)
l_all = list(df_test['words'].head(10))
l_all
#plt.bar(df_test['words'],df_test['counts'])
# Out:
# ['time', 'love', 'youre', 'ill', 'day', 'ive', 'life', 'eyes', 'baby', 'night']

# %%
small_not = np.setdiff1d(l_all,l_small)
list(small_not)
# Out:
# ['night']

# %% [markdown]
# #### It seems that we are half right to approach the assumption! For those artist with lower vocabulary, they tends to use "popular words".<font color='red'> "Night" </font> is the only one that in genral - poplular - group but not in popular group for lower vacabulary artist.
#
# #### Now let's do the same thing for the group of artits who seems to know more words.

# %%
bar_plot_freq('artist',artist_larger,10)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# The list of words for artists with higher vocabulary.

# %%
large_list = list_counts_common_word('artist',artist_larger,10)
df_larger = df_counts_words(large_list,None)
l_large = list(df_larger['words'].head(10))
l_large
#plt.bar(df_test['words'],df_test['counts'])
# Out:
# ['wave',
#  'romance',
#  'worm',
#  'soul',
#  'pain',
#  'youre',
#  'head',
#  'play',
#  'game',
#  'mine']

# %% [markdown]
# The differnce of general popular words and popular words for artist in larger vocabulary group

# %%
large_not = np.setdiff1d(l_all,l_large)
list(large_not)
# Out:
# ['baby', 'day', 'eyes', 'ill', 'ive', 'life', 'love', 'night', 'time']

# %% [markdown]
# #### Among this diff_list result, it says that except <font color='red'> "youre"</font> in the gerneral -popular - group, all other general popular words is not the favourite words for those artits has higher vacabulary.  Which can be conclude as :<font color='green'> the higher the vacabulary that aritst has, the less likly he or she tends to use "the general popular words"</font>

# %%
# A dataframe that counts for different artist, do they tend to repeat words or now. the larger the value is, the less likely they repeat the words
lists_artist_floatwords=[]
for name in artist_list:
    lists_artist_floatwords.append(float_words_artist_main(name))
df_artist_percentage_unique = pd.DataFrame(lists_artist_floatwords,columns=['artist','percentage_unique_words'])
df_artist_percentage_unique = df_artist_percentage_unique.sort_values('percentage_unique_words',ascending=False)

df_artist_percentage_unique.head(20)

# %%
df_counts_word_main('focus','artist',int_common = 5)
# Out:
#       words  counts
# 1      wave       3
# 0      move       2
# 13  impulse       2
# 10     calm       1
# 17    reach       1

# %%
df_counts_word_main('daughters','artist',int_common = 5)
# Out:
#       words  counts
# 66      lie      11
# 80  cologne       6
# 63     fall       6
# 79     girl       6
# 84   future       5

# %%
df_counts_word_main('daft-punk','artist',int_common = 5)
# Out:
#           words  counts
# 18        world     299
# 5          rock     226
# 208       night     208
# 117       human     207
# 116  somethings     163

# %%
df_counts_word_main('bon-jovi','artist',int_common = 5)
# Out:
#      words  counts
# 27    love     834
# 244   baby     491
# 41   youre     456
# 209  night     405
# 146   time     388

# %%
df_counts_word_main('dragonforce','artist',int_common = 5)
# Out:
#     words  counts
# 19   time     189
# 17   fire     137
# 12  stand     135
# 20   burn     134
# 84    day     130

# %%
df_test = df_counts_word_main(origin_list[10],'origin',int_common=20)

df_test2 = df_counts_word_main(origin_list[9],'origin',int_common=20)

df_test3 = df_counts_word_main(origin_list[8],'origin',int_common=20)
l_t1 = list(df_test['words'])
l_t2 = list(df_test2['words'])
l_t3 = list(df_test3['words'])
l_t_list = [l_t2,l_t3]

# %%
bar_plot_freq('genre',10)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(df_test['words'],df_test['counts'])

# %%
df_counts_words(l_list,None).head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-12c1bda04d1f> in <module>
# ----> 1 df_counts_words(l_list,None).head(5)
#
# NameError: name 'l_list' is not defined

# %%
l_word_dup = []
l_word_dup_sum = []
for l in l_list:
    for word in l:
        if word in l_t1:
            l_word_dup.append(word)
    l_word_dup_sum.append(l_word_dup)

# %%
#word_cloud_via_genre('Pop',int_common=10)

# %%
#word_cloud_via_genre('Folk',int_common=10)

# %%
#df_join_lyrics_artist.head()

# %%
genre_list
# Out:
# ['Electronic',
#  'Not Available',
#  'Rock',
#  'Metal',
#  'R&B',
#  'Other',
#  'Indie',
#  'Folk',
#  'Country',
#  'Jazz',
#  'Hip-Hop',
#  'Pop']

# %%
df_genre1 = df_genre_joined(genre_list[1])

# %%
df_genre1.head()
# Out:
#       year        artist          genre  \
# 6289  2009  alexisonfire  Not Available
# 6290  2009  alexisonfire  Not Available
# 6291  2009  alexisonfire  Not Available
# 6292  2009  alexisonfire  Not Available
# 6293  2009  alexisonfire  Not Available
#
#                                            stemmedwords  \
# 6289  concerned common day evil mind push divide for...
# 6290  winter snow fall town dress white skin burn wi...
# 6291  pregnant teen barton street bus homeless peopl...
# 6292  count accept crime bethlehem galilee accept cr...
# 6293  nameless victim generation lost searching exis...
#
#                                                   Intro  Formed  \
# 6289  \n                                        Alex...  2001.0
# 6290  \n                                        Alex...  2001.0
# 6291  \n                                        Alex...  2001.0
# 6292  \n                                        Alex...  2001.0
# 6293  \n                                        Alex...  2001.0
#
#                                                 Members  \
# 6289  \n                                            ...
# 6290  \n                                            ...
# 6291  \n                                            ...
# 6292  \n                                            ...
# 6293  \n                                            ...
#
#                                Origin
# 6289  St. Catharines, Ontario, Canada
# 6290  St. Catharines, Ontario, Canada
# 6291  St. Catharines, Ontario, Canada
# 6292  St. Catharines, Ontario, Canada
# 6293  St. Catharines, Ontario, Canada

# %%
df_genre1['Origin'].value_counts().plot.bar()

# %%
df_genre_joined(genre_list[0])['Origin'].value_counts().plot.bar()

# %%
word_cloud_plot(list(df_genre1['Origin']),int_common=3)

# %%
df_counts_words(list(df_genre_joined(genre_list[0])['Origin']),3)
# Out:
#              words  counts
# 1  London, England      93
# 0    Paris, France      55

# %%
df_counts_words(list(df_genre_joined(genre_list[1])['Origin']),3)
# Out:
#                              words  counts
# 6                      Chicago, IL     182
# 0  St. Catharines, Ontario, Canada      59
# 5                        Australia      39

# %%
df_counts_words(list(df_genre_joined(genre_list[3])['Origin']),3)
# Out:
#                 words  counts
# 6              Sweden     244
# 17  San Francisco, CA     170
# 13   Suffolk, England      98

# %%
df_counts_words(list(df_genre_joined(genre_list[4])['Origin']),3)
# Out:
#             words  counts
# 1  Pittsburgh, PA     182
# 0  Stillwater, OK      82
# 2    New York, NY       8

# %%
df_counts_words(list(df_genre_joined(genre_list[6])['Origin']),3)
# Out:
#      words  counts
# 0  England      48

# %%
df_counts_words(list(df_genre_joined(genre_list[7])['Origin']),3)
# Out:
#           words  counts
# 0  New York, NY      13

# %%
df_counts_words(list(df_genre_joined(genre_list[8])['Origin']),3)
# Out:
#                       words  counts
# 0  Toronto, Ontario, Canada     195

# %%
 df_origin(origin_list[6])
# Out:
#         year                artist  genre  \
# 25084   2009               bayside   Rock
# 25085   2009               bayside   Rock
# 25086   2009               bayside   Rock
# 25087   2007               bayside   Rock
# 25088   2007               bayside   Rock
# 25089   2007               bayside   Rock
# 25090   2007               bayside   Rock
# 25091   2007               bayside   Rock
# 25092   2007               bayside   Rock
# 25093   2007               bayside   Rock
# 25094   2007               bayside   Rock
# 25095   2007               bayside   Rock
# 25096   2007               bayside   Rock
# 25097   2007               bayside   Rock
# 25098   2007               bayside   Rock
# 25099   2007               bayside   Rock
# 25100   2007               bayside   Rock
# 25101   2007               bayside   Rock
# 25102   2007               bayside   Rock
# 25103   2007               bayside   Rock
# 25104   2007               bayside   Rock
# 25105   2007               bayside   Rock
# 25106   2007               bayside   Rock
# 25107   2007               bayside   Rock
# 25108   2007               bayside   Rock
# 25109   2007               bayside   Rock
# 25110   2007               bayside   Rock
# 25111   2007               bayside   Rock
# 25112   2007               bayside   Rock
# 25113   2007               bayside   Rock
# ...      ...                   ...    ...
# 113906  2006  from-autumn-to-ashes  Metal
# 113907  2006  from-autumn-to-ashes  Metal
# 113908  2006  from-autumn-to-ashes  Metal
# 113909  2006  from-autumn-to-ashes  Metal
# 113910  2006  from-autumn-to-ashes  Metal
# 113911  2006  from-autumn-to-ashes  Metal
# 113912  2006  from-autumn-to-ashes  Metal
# 113913  2006  from-autumn-to-ashes  Metal
# 113914  2006  from-autumn-to-ashes  Metal
# 113915  2006  from-autumn-to-ashes  Metal
# 113916  2006  from-autumn-to-ashes  Metal
# 113917  2006  from-autumn-to-ashes  Metal
# 113918  2006  from-autumn-to-ashes  Metal
# 113919  2006  from-autumn-to-ashes  Metal
# 113920  2006  from-autumn-to-ashes  Metal
# 113921  2006  from-autumn-to-ashes  Metal
# 113922  2006  from-autumn-to-ashes  Metal
# 113923  2006  from-autumn-to-ashes  Metal
# 113924  2006  from-autumn-to-ashes  Metal
# 113925  2008  from-autumn-to-ashes  Metal
# 113926  2008  from-autumn-to-ashes  Metal
# 113927  2008  from-autumn-to-ashes  Metal
# 113928  2008  from-autumn-to-ashes  Metal
# 113929  2008  from-autumn-to-ashes  Metal
# 113930  2008  from-autumn-to-ashes  Metal
# 113931  2008  from-autumn-to-ashes  Metal
# 113932  2008  from-autumn-to-ashes  Metal
# 113933  2008  from-autumn-to-ashes  Metal
# 113934  2008  from-autumn-to-ashes  Metal
# 113935  2008  from-autumn-to-ashes  Metal
#
#                                              stemmedwords  \
# 25084   nighttime fade day mistake didnt fate doesnt c...
# 25085   learn matter didnt someday define hate lesson ...
# 25105   \n                                            ...  Long Island, NY
# 25106   \n                                            ...  Long Island, NY
# 25107   \n                                            ...  Long Island, NY
# 25108   \n                                            ...  Long Island, NY
# 25109   \n                                            ...  Long Island, NY
# 25110   \n                                            ...  Long Island, NY
# 25111   \n                                            ...  Long Island, NY
# 25112   \n                                            ...  Long Island, NY
# 25113   \n                                            ...  Long Island, NY
# ...                                                   ...              ...
# 113906  \n                                            ...  Long Island, NY
# 113907  \n                                            ...  Long Island, NY
# 113908  \n                                            ...  Long Island, NY
# 113909  \n                                            ...  Long Island, NY
# 113910  \n                                            ...  Long Island, NY
# 113911  \n                                            ...  Long Island, NY
# 113912  \n                                            ...  Long Island, NY
# 113913  \n                                            ...  Long Island, NY
# 113914  \n                                            ...  Long Island, NY
# 113915  \n                                            ...  Long Island, NY
# 113916  \n                                            ...  Long Island, NY
# 113917  \n                                            ...  Long Island, NY
# 113918  \n                                            ...  Long Island, NY
# 113919  \n                                            ...  Long Island, NY
# 113920  \n                                            ...  Long Island, NY
# 113921  \n                                            ...  Long Island, NY
# 113922  \n                                            ...  Long Island, NY
# 113923  \n                                            ...  Long Island, NY
# 113924  \n                                            ...  Long Island, NY
# 113925  \n                                            ...  Long Island, NY
# 113926  \n                                            ...  Long Island, NY
# 113927  \n                                            ...  Long Island, NY
# 113928  \n                                            ...  Long Island, NY
# 113929  \n                                            ...  Long Island, NY
# 113930  \n                                            ...  Long Island, NY
# 113931  \n                                            ...  Long Island, NY
# 113932  \n                                            ...  Long Island, NY
# 113933  \n                                            ...  Long Island, NY
# 113934  \n                                            ...  Long Island, NY
# 113935  \n                                            ...  Long Island, NY
#
# [133 rows x 8 columns]

# %%
 len(set(df_origin(origin_list[6])['genre']))
# Out:
# 2

# %%
def num_genre_in_origin(origin_str):
    return [len(set(df_origin(origin_str)['genre'])),list(set(df_origin(origin_str)['genre'])),origin_str]

# %%
num_orin = []
genre_type =[]
orin = []


num_genre_in_origin(origin_list[6])
# Out:
# [2, ['Rock', 'Metal'], 'Long Island, NY']

# %%
num_orin = []
genre_type =[]
orin = []
for o in origin_list:
    num_orin.append(num_genre_in_origin(o)[0])
    genre_type.append(num_genre_in_origin(o)[1])
    orin.append(num_genre_in_origin(o)[2])

# %%
df_ori_num_type = pd.DataFrame(
    {'lst1Title': num_orin,
     'lst2Title': genre_type,
     'lst3Title': orin
    })

# %%
df_ori_num_type[df_ori_num_type['lst3Title'] == 'Belgium']
# Out:
#     lst1Title lst2Title lst3Title
# 37          1   [Metal]   Belgium

# %%
df_add_words( df_origin(origin_list[6]))
# Out:
#         year                artist  genre  \
# 25084   2009               bayside   Rock
# 25085   2009               bayside   Rock
# 25086   2009               bayside   Rock
# 25087   2007               bayside   Rock
# 25088   2007               bayside   Rock
# 25089   2007               bayside   Rock
# 25090   2007               bayside   Rock
# 25091   2007               bayside   Rock
# 25092   2007               bayside   Rock
# 25093   2007               bayside   Rock
# 25094   2007               bayside   Rock
# 25095   2007               bayside   Rock
# 25096   2007               bayside   Rock
# 113916  [hand, door, serenity, steal, life, climb, siz...
# 113917  [world, despair, live, warning, die, design, w...
# 113918  [forever, identify, patient, xy, configuration...
# 113919  [inside, empty, left, confused, scared, confus...
# 113920  [provide, gates, steady, pilot, half, afraid, ...
# 113921  [result, meet, late, night, dinner, eat, sit, ...
# 113922  [creation, imperfections, defy, swollen, ego, ...
# 113923  [tears, suspended, smile, empty, love, locked,...
# 113924  [sad, life, reduced, single, apartment, mattre...
# 113925  [time, walk, dock, welcoming, morning, sun, sh...
# 113926  [tears, suspended, smile, locked, door, foreve...
# 113927  [innocent, victim, exist, told, outfit, nation...
# 113928  [forever, identify, patient, xy, configuration...
# 113929  [monument, matron, quick, change, mood, nervou...
# 113930  [dismiss, telegram, exhibit, pile, paper, boun...
# 113931  [extract, move, aggravation, current, mood, cl...
# 113932  [honor, honor, explain, behavior, honor, honor...
# 113933  [elementary, eavesdropper, theyre, comprehend,...
# 113934  [press, business, comfort, expensive, hot, sho...
# 113935  [coarse, exhale, lungs, pray, pity, fingers, p...
#
# [133 rows x 9 columns]

# %%
#df_counts_words (list(set(list_all_words(df_add_words( df_origin(origin_list[6]))))))

# %%
list(df_counts_words (list((list_all_words(df_add_words( df_origin(origin_list[1]))))))['words'][:5])
# Out:
# ['bother', 'tonight', 'day', 'jukin', 'lover']

# %%
word_cloud_plot(list((list_all_words(df_add_words( df_origin(origin_list[1]))))),5)

# %%
list(df_counts_words (list((list_all_words(df_add_words( df_origin(origin_list[1]))))))['words'][:5])

# %%
ori_list

# %%
ori_list = []
for ori in origin_list:
    if 'love' not in list(df_counts_words (list((list_all_words(df_add_words( df_origin(ori))))))['words'][:5]) and 'time' not in list(df_counts_words (list((list_all_words(df_add_words( df_origin(ori))))))['words'][:5]):
        ori_list.append(ori)
        print(ori)
        word_cloud_plot(list((list_all_words(df_add_words( df_origin(ori))))),5)
# Out:
# Doraville, GA
# Ottawa, Ontario, Canada
# Gothenburg, Sweden
# Santa Barbara, CA
# Maryland
# Belgium
# Boca Raton, FL
# Cumbria, England
# Paris, France
# Brooklyn, NY
# Middelburg, Netherlands
# Montreal, Quebec, Canada
# Sydney, Australia
# Tumba, Sweden
# Amsterdam, The Netherlands
# Arles, France
# Sulphur Springs, TX
# Providence, RI
# Wilkes-Barre, PA
# San Diego, CA

# %%
df_genre('Metal')
# Out:
#                                        song  year                 artist  \
# 86                   the-complete-emptiness  2007     a-canorous-quintet
# 87                                 the-void  2007     a-canorous-quintet
# 88                              retaliation  2007     a-canorous-quintet
# 89                                the-storm  2007     a-canorous-quintet
# 90                            realm-of-rain  2007     a-canorous-quintet
# 91                             selfdeceiver  2007     a-canorous-quintet
# 92                                      red  2007     a-canorous-quintet
# 93                         land-of-the-lost  2007     a-canorous-quintet
# 94                           embryo-of-lies  2007     a-canorous-quintet
# 95                                everbleed  2007     a-canorous-quintet
# 96                         the-black-spiral  2006     a-canorous-quintet
# 97                     naked-with-open-eyes  2006     a-canorous-quintet
# 98                               spellbound  2006     a-canorous-quintet
